# %% [markdown]
# # General Feedback on Assignment 4
#
#
# This feedback is condensed out of your hand-ins.
#
#
# ## Copied code and semantics of code
#
# Why did I see so many hand-ins, in which the code looks so much alike the code of other groups? **That is not cool!** Especially, when you copy code make sure you understand what it is doing and that it actually does what the assignment asks you to do. For example:
#
# If the assignment says _"...price per square meter is lower than 80000Dkk..."_ then code like:
#
# ```python
# if price_per_sqm >= 80.000:
#     pass
# ```
#
# Expresses something quite different, no? First, it says that the price per square meter (`price_per_sqm`) shall be **larger or equal** to **80**. In Python a dot `.` in a number is always a decimal separator:

# %%
price_per_sqm = 49000
if price_per_sqm >= 80.000:
    print(price_per_sqm)
    
print(80.000)
print(80000)
print(type(80.000))
print(type(80000))
# Out:
# 49000
# 80.0
# 80000
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ## Reproducibility
#
# Many hand-ins are not reproducible. Make sure that the code you hand-in is **complete**, that is if I run the program and it cannot find the data that you are reading and there are no corresponding files in the release then the solution is not reproducible. Furthermore, when you comment out some code that generated your plots and I have to configure something for regenerating your images then your results are not reproducible neither.

# %% [markdown]
# ## Plotting values
#
# When you plot values, then -depending on what you wnat to show- you very likely do not want to sort the collections you plot. For example if we have a list of hypothetical prices per square meter `prices` in the following and an index corresponding to a flat in the order of your visit. Plotting the price per flat in order produces the following.

# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt


prices = [33113, 33091, 33082, 33246, 30609, 33434, 29775, 29798, 30716,
          29608, 30969, 30215, 29858, 29742, 33781, 29704, 31506, 31374, 
          31007, 29985, 28877, 30180, 30823, 34146, 30956, 31794, 31118, 
          32402, 31581, 31981, 34208, 29416, 29864, 29803, 29685, 29627, 
          32043, 30059, 30861, 29861, 34761, 32479, 31053, 30032, 30384, 
          29086, 30547, 32090, 31049, 30069, 28440, 31647, 30208, 30218, 
          29427, 29517, 29485, 29751, 28761, 30876, 30454, 32236, 29462, 
          29981, 31215, 33297, 32794, 28853, 29355, 30191, 28903, 30662, 
          35104, 30973, 31806, 30214, 30611, 31042, 30332, 30922, 28641, 
          30216, 29456, 32020, 30208, 29626, 31282, 31616, 30182, 31519, 
          30623, 31436, 28742, 31451, 31776, 31101, 33880, 33310, 28790, 
          30389, 29850, 34909, 30236, 28527, 32258, 29776, 31170, 32837, 
          30715, 30100, 31335, 30244, 31327, 31665, 32475, 33163, 30577, 
          34053, 31502, 33733, 30587, 28828, 33891, 30833, 30679, 31766, 
          33337, 29224, 31059, 35899, 31219, 31885, 32532, 29488, 31138, 
          29324, 30120, 29988, 30511, 32373, 30508, 30851, 29347, 30105, 
          30956, 28613, 30243, 30068, 30035, 31198, 30968, 30909, 30607, 
          32372, 31019, 30857, 31630, 29803, 30998, 29141, 49006, 46467, 
          47506, 48882, 46979, 46130, 44102, 30172, 29532, 30163, 30641, 
          29659, 30528, 30714, 30072, 29576, 29530, 30615, 28745, 30333, 
          46654, 46997, 52564, 40077, 30440, 29543, 34735, 31273, 30405, 
          33923, 49933, 43763, 30867, 34188, 30457, 29890, 32361, 28737, 
          43483, 52044]

idxs = list(range(len(prices)))
plt.scatter(idxs, prices)
plt
# Out:
# <img src="data:image/png;base64,..." width="640">
# <module 'matplotlib.pyplot' from '/home/vagrant/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Now, you can see that you visited the most expensive flats in the end.
#
# However, if you sort the prices, then of course you plot how the prices are increasing. That is not necessarily what you want to show.

# %%
# %matplotlib notebook

plt.scatter(idxs, sorted(prices))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Plotting Histograms
#
# When you plot a cummulative histogram, for data where you want to split on frequency values (typically y-axis). Then the values on the x-axis cannot change for the same dataset. See the example below.

# %%
# %matplotlib notebook


freq, vals = np.histogram(prices, bins='auto')
plt.bar(vals[:-1], freq, width=500, linewidth=0, align='center')
plt
# Out:
# <img src="data:image/png;base64,..." width="640">
# <module 'matplotlib.pyplot' from '/home/vagrant/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %%
# %matplotlib notebook

# just to generate some example splits of data
freqs = []
for f in freq:
    fst_bound = f // 2
    snd_bound = fst_bound // 3
    freqs.append((fst_bound, snd_bound, f - (fst_bound + snd_bound)))

freqs_low, freqs_medium, freqs_high = zip(*freqs)
plt.bar(vals[:-1], freqs_low, width=500, linewidth=0, align='center')
plt.bar(vals[:-1], freqs_medium, width=500, linewidth=0, align='center', bottom=freqs_low)
plt.bar(vals[:-1], freqs_high, width=500, linewidth=0, align='center', bottom=freqs_medium)
plt
# Out:
# <img src="data:image/png;base64,..." width="640">
# <module 'matplotlib.pyplot' from '/home/vagrant/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # Formulating a hypothesis about relations
#
# The idea with the task was to let you say how certain values are related. Many of you said something along the lines: _"The longer away from Nørreport st. the cheaper the price per square meter"_. That is an okay hypothesis but unfortunatelly it is not quite sharp.
#
# If you look at the following image, which plots some example data, then you can see that the hypothesis sentence would hold for both distributions of example values. However, you can see that the two distributions are qualitatively different. One falls linearly and the other one falls way more steeply i the beginning but than it just stabilizes right arround 50000. That is, when formulating hypothesis try to formulate whcih underlyning model you expect. Jens will tell you more about that.

# %%
# %matplotlib notebook

m = 10000
x = np.arange(1, m + 1)
delta = np.random.uniform(-5000, 5000, size=(m,))
y = (1 / x ** 0.1) * 100000 + delta

plt.scatter(x, y, s=.05)
#plt.plot(x, (1 / x ** 0.1) * 100000)

y_lin = -10 * x + 100000 + delta

plt.scatter(x, y_lin, s=.05, c='y')
#plt.plot(x, -10 * x + 100000, c='y')
plt.axis([-100,10000, 0, 100000])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [-100, 10000, 0, 100000]

# %% [markdown]
# ## Redefining Keywords
#
# It is not a good idea to redefine keywords in Python. That is, a variable should not be called `zip` as there is a function with that name. For example, the `zip` function zips collections into tuples.

# %%
for el in zip([1, 2, 3], ['a', 'b', 'c']):
    print(el)
# Out:
# (1, 'a')
# (2, 'b')
# (3, 'c')

# %% [markdown]
# When you redefine `zip` then your program might behave unexpectetly. For example, the following prints `2200` as expected

# %%
zip = 2200
print(zip)
# Out:
# 2200

# %% [markdown]
# However, now following code raises an exception.

# %%
zip = 2200

for el in zip([1, 2, 3], ['a', 'b', 'c']):
    print(el)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2c9c98861243> in <module>()
#       1 zip = 2200
#       2
# ----> 3 for el in zip([1, 2, 3], ['a', 'b', 'c']):
#       4     print(el)
#
# TypeError: 'int' object is not callable
